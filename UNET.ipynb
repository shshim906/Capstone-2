# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
# Set some parameters
im_width = 128
im_height = 128
border = 5

# %%
filelist=os.listdir("/home/seo/ISIC DATA")
meta=[file for file in filelist if not file.endswith(".jpeg") and not file.endswith(".png") and file.startswith("ISIC")]
pics=[file for file in filelist if (file.endswith(".jpeg") or file.endswith(".png")) and file.startswith("ISIC")]
masklist=os.listdir("/home/seo/Masks")
masks=[file for file in masklist if file.endswith(".png") and file.startswith("ISIC")]
masks
# Out:
# ['ISIC_0012653_segmentation.png',
#  'ISIC_0000116_segmentation.png',
#  'ISIC_0014985_segmentation.png',
#  'ISIC_0000098_segmentation.png',
#  'ISIC_0010186_segmentation.png',
#  'ISIC_0010344_segmentation.png',
#  'ISIC_0000018_segmentation.png',
#  'ISIC_0012324_segmentation.png',
#  'ISIC_0010252_segmentation.png',
#  'ISIC_0013120_segmentation.png',
#  'ISIC_0000326_segmentation.png',
#  'ISIC_0000409_segmentation.png',
#  'ISIC_0010358_segmentation.png',
#  'ISIC_0013031_segmentation.png',
#  'ISIC_0012363_segmentation.png',
#  'ISIC_0010191_segmentation.png',
#  'ISIC_0010062_segmentation.png',
#  'ISIC_0015200_segmentation.png',
#  'ISIC_0000236_segmentation.png',
#  'ISIC_0011292_segmentation.png',
#  'ISIC_0011225_segmentation.png',
#  'ISIC_0010093_segmentation.png',
#  'ISIC_0000358_segmentation.png',
#  'ISIC_0000137_segmentation.png',
#  'ISIC_0010603_segmentation.png',
#  'ISIC_0012988_segmentation.png',
#  'ISIC_0014291_segmentation.png',
#  'ISIC_0010844_segmentation.png',
#  'ISIC_0015956_segmentation.png',
#  'ISIC_0000161_segmentation.png',
#  'ISIC_0014834_segmentation.png',
#  'ISIC_0010318_segmentation.png',
#  'ISIC_0015390_segmentation.png',
#  'ISIC_0015631_segmentation.png',
#  'ISIC_0014982_segmentation.png',
#  'ISIC_0013224_segmentation.png',
#  'ISIC_0012108_segmentation.png',
#  'ISIC_0013163_segmentation.png',
#  'ISIC_0000353_segmentation.png',
#  'ISIC_0012357_segmentation.png',
#  'ISIC_0012793_segmentation.png',
#  'ISIC_0000493_segmentation.png',
#  'ISIC_0002093_segmentation.png',
#  'ISIC_0008913_segmentation.png',
#  'ISIC_0001262_segmentation.png',
#  'ISIC_0012235_segmentation.png',
#  'ISIC_0000044_segmentation.png',
#  'ISIC_0011224_segmentation.png',
#  'ISIC_0011163_segmentation.png',
#  'ISIC_0013942_segmentation.png',
#  'ISIC_0014890_segmentation.png',
#  'ISIC_0000183_segmentation.png',
#  'ISIC_0013758_segmentation.png',
#  'ISIC_0000259_segmentation.png',
#  'ISIC_0010492_segmentation.png',
#  'ISIC_0013428_segmentation.png',
#  'ISIC_0012233_segmentation.png',
#  'ISIC_0010063_segmentation.png',
#  'ISIC_0014195_segmentation.png',
#  'ISIC_0000231_segmentation.png',
#  'ISIC_0002246_segmentation.png',
#  'ISIC_0002439_segmentation.png',
#  'ISIC_0013516_segmentation.png',
#  'ISIC_0013762_segmentation.png',
#  'ISIC_0008528_segmentation.png',
#  'ISIC_0012261_segmentation.png',
#  'ISIC_0015944_segmentation.png',
#  'ISIC_0012521_segmentation.png',
#  'ISIC_0000001_segmentation.png',
#  'ISIC_0012957_segmentation.png',
#  'ISIC_0013000_segmentation.png',
#  'ISIC_0011167_segmentation.png',
#  'ISIC_0014944_segmentation.png',
#  'ISIC_0015298_segmentation.png',
#  'ISIC_0014486_segmentation.png',
#  'ISIC_0014166_segmentation.png',
#  'ISIC_0015144_segmentation.png',
#  'ISIC_0011359_segmentation.png',
#  'ISIC_0014904_segmentation.png',
#  'ISIC_0012813_segmentation.png',
#  'ISIC_0014580_segmentation.png',
#  'ISIC_0000015_segmentation.png',
#  'ISIC_0014853_segmentation.png',
#  'ISIC_0000021_segmentation.png',
#  'ISIC_0015939_segmentation.png',
#  'ISIC_0014879_segmentation.png',
#  'ISIC_0015206_segmentation.png',
#  'ISIC_0009979_segmentation.png',
#  'ISIC_0000120_segmentation.png',
#  'ISIC_0000077_segmentation.png',
#  'ISIC_0011157_segmentation.png',
#  'ISIC_0010357_segmentation.png',
#  'ISIC_0010256_segmentation.png',
#  'ISIC_0012803_segmentation.png',
#  'ISIC_0012883_segmentation.png',
#  'ISIC_0010018_segmentation.png',
#  'ISIC_0012159_segmentation.png',
#  'ISIC_0012699_segmentation.png',
#  'ISIC_0000465_segmentation.png',
#  'ISIC_0002829_segmentation.png',
#  'ISIC_0014026_segmentation.png',
#  'ISIC_0014547_segmentation.png',
#  'ISIC_0014788_segmentation.png',
#  'ISIC_0009980_segmentation.png',
#  'ISIC_0014366_segmentation.png',
#  'ISIC_0015204_segmentation.png',
#  'ISIC_0000108_segmentation.png',
#  'ISIC_0013027_segmentation.png',
#  'ISIC_0012656_segmentation.png',
#  'ISIC_0000999_segmentation.png',
#  'ISIC_0015973_segmentation.png',
#  'ISIC_0000460_segmentation.png',
#  'ISIC_0009987_segmentation.png',
#  'ISIC_0013617_segmentation.png',
#  'ISIC_0000540_segmentation.png',
#  'ISIC_0003728_segmentation.png',
#  'ISIC_0000088_segmentation.png',
#  'ISIC_0009874_segmentation.png',
#  'ISIC_0012417_segmentation.png',
#  'ISIC_0012673_segmentation.png',
#  'ISIC_0014286_segmentation.png',
#  'ISIC_0009917_segmentation.png',
#  'ISIC_0014238_segmentation.png',
#  'ISIC_0013637_segmentation.png',
#  'ISIC_0012298_segmentation.png',
#  'ISIC_0014860_segmentation.png',
#  'ISIC_0010192_segmentation.png',
#  'ISIC_0015256_segmentation.png',
#  'ISIC_0011301_segmentation.png',
#  'ISIC_0014698_segmentation.png',
#  'ISIC_0014883_segmentation.png',
#  'ISIC_0013712_segmentation.png',
#  'ISIC_0012432_segmentation.png',
#  'ISIC_0015161_segmentation.png',
#  'ISIC_0015156_segmentation.png',
#  'ISIC_0000329_segmentation.png',
#  'ISIC_0000113_segmentation.png',
#  'ISIC_0013696_segmentation.png',
#  'ISIC_0009976_segmentation.png',
#  'ISIC_0013398_segmentation.png',
#  'ISIC_0001102_segmentation.png',
#  'ISIC_0014325_segmentation.png',
#  'ISIC_0009929_segmentation.png',
#  'ISIC_0014433_segmentation.png',
#  'ISIC_0010057_segmentation.png',
#  'ISIC_0010581_segmentation.png',
#  'ISIC_0011213_segmentation.png',
#  'ISIC_0013804_segmentation.png',
#  'ISIC_0000292_segmentation.png',
#  'ISIC_0000287_segmentation.png',
#  'ISIC_0014771_segmentation.png',
#  'ISIC_0000020_segmentation.png',
#  'ISIC_0014076_segmentation.png',
#  'ISIC_0000538_segmentation.png',
#  'ISIC_0006651_segmentation.png',
#  'ISIC_0011090_segmentation.png',
#  'ISIC_0012221_segmentation.png',
#  'ISIC_0010593_segmentation.png',
#  'ISIC_0015044_segmentation.png',
#  'ISIC_0012804_segmentation.png',
#  'ISIC_0014498_segmentation.png',
#  'ISIC_0008256_segmentation.png',
#  'ISIC_0000300_segmentation.png',
#  'ISIC_0016034_segmentation.png',
#  'ISIC_0016017_segmentation.png',
#  'ISIC_0013499_segmentation.png',
#  'ISIC_0013972_segmentation.png',
#  'ISIC_0010598_segmentation.png',
#  'ISIC_0000225_segmentation.png',
#  'ISIC_0000064_segmentation.png',
#  'ISIC_0000297_segmentation.png',
#  'ISIC_0011099_segmentation.png',
#  'ISIC_0013177_segmentation.png',
#  'ISIC_0013793_segmentation.png',
#  'ISIC_0012342_segmentation.png',
#  'ISIC_0013035_segmentation.png',
#  'ISIC_0015254_segmentation.png',
#  'ISIC_0011083_segmentation.png',
#  'ISIC_0014072_segmentation.png',
#  'ISIC_0014867_segmentation.png',
#  'ISIC_0013015_segmentation.png',
#  'ISIC_0000212_segmentation.png',
#  'ISIC_0000152_segmentation.png',
#  'ISIC_0012107_segmentation.png',
#  'ISIC_0013487_segmentation.png',
#  'ISIC_0013489_segmentation.png',
#  'ISIC_0014103_segmentation.png',
#  'ISIC_0014473_segmentation.png',
#  'ISIC_0009967_segmentation.png',
#  'ISIC_0013082_segmentation.png',
#  'ISIC_0012285_segmentation.png',
#  'ISIC_0000383_segmentation.png',
#  'ISIC_0014574_segmentation.png',
#  'ISIC_0013275_segmentation.png',
#  'ISIC_0008659_segmentation.png',
#  'ISIC_0000004_segmentation.png',
#  'ISIC_0014708_segmentation.png',
#  'ISIC_0012137_segmentation.png',
#  'ISIC_0014961_segmentation.png',
#  'ISIC_0010356_segmentation.png',
#  'ISIC_0000261_segmentation.png',
#  'ISIC_0011229_segmentation.png',
#  'ISIC_0000360_segmentation.png',
#  'ISIC_0001267_segmentation.png',
#  'ISIC_0000547_segmentation.png',
#  'ISIC_0013024_segmentation.png',
#  'ISIC_0000391_segmentation.png',
#  'ISIC_0012248_segmentation.png',
#  'ISIC_0000095_segmentation.png',
#  'ISIC_0013227_segmentation.png',
#  'ISIC_0012245_segmentation.png',
#  'ISIC_0010171_segmentation.png',
#  'ISIC_0001185_segmentation.png',
#  'ISIC_0010070_segmentation.png',
#  'ISIC_0000359_segmentation.png',
#  'ISIC_0000536_segmentation.png',
#  'ISIC_0010861_segmentation.png',
#  'ISIC_0016024_segmentation.png',
#  'ISIC_0013680_segmentation.png',
#  'ISIC_0013809_segmentation.png',
#  'ISIC_0007475_segmentation.png',
#  'ISIC_0012290_segmentation.png',
#  'ISIC_0010480_segmentation.png',
#  'ISIC_0012356_segmentation.png',
#  'ISIC_0000323_segmentation.png',
#  'ISIC_0014872_segmentation.png',
#  'ISIC_0012384_segmentation.png',
#  'ISIC_0010016_segmentation.png',
#  'ISIC_0013172_segmentation.png',
#  'ISIC_0013178_segmentation.png',
#  'ISIC_0001188_segmentation.png',
#  'ISIC_0013970_segmentation.png',
#  'ISIC_0012679_segmentation.png',
#  'ISIC_0010360_segmentation.png',
#  'ISIC_0014190_segmentation.png',
#  'ISIC_0000234_segmentation.png',
#  'ISIC_0014937_segmentation.png',
#  'ISIC_0012670_segmentation.png',
#  'ISIC_0009977_segmentation.png',
#  'ISIC_0012961_segmentation.png',
#  'ISIC_0011227_segmentation.png',
#  'ISIC_0013208_segmentation.png',
#  'ISIC_0013287_segmentation.png',
#  'ISIC_0012151_segmentation.png',
#  'ISIC_0016044_segmentation.png',
#  'ISIC_0012358_segmentation.png',
#  'ISIC_0014395_segmentation.png',
#  'ISIC_0013948_segmentation.png',
#  'ISIC_0014458_segmentation.png',
#  'ISIC_0000074_segmentation.png',
#  'ISIC_0013410_segmentation.png',
#  'ISIC_0014854_segmentation.png',
#  'ISIC_0014249_segmentation.png',
#  'ISIC_0010346_segmentation.png',
#  'ISIC_0000057_segmentation.png',
#  'ISIC_0000451_segmentation.png',
#  'ISIC_0000063_segmentation.png',
#  'ISIC_0013802_segmentation.png',
#  'ISIC_0011220_segmentation.png',
#  'ISIC_0006021_segmentation.png',
#  'ISIC_0012741_segmentation.png',
#  'ISIC_0010552_segmentation.png',
#  'ISIC_0000155_segmentation.png',
#  'ISIC_0014158_segmentation.png',
#  'ISIC_0008396_segmentation.png',
#  'ISIC_0013461_segmentation.png',
#  'ISIC_0015023_segmentation.png',
#  'ISIC_0014677_segmentation.png',
#  'ISIC_0014028_segmentation.png',
#  'ISIC_0015020_segmentation.png',
#  'ISIC_0001385_segmentation.png',
#  'ISIC_0015270_segmentation.png',
#  'ISIC_0013147_segmentation.png',
#  'ISIC_0009972_segmentation.png',
#  'ISIC_0016062_segmentation.png',
#  'ISIC_0000227_segmentation.png',
#  'ISIC_0003346_segmentation.png',
#  'ISIC_0013747_segmentation.png',
#  'ISIC_0010856_segmentation.png',
#  'ISIC_0014742_segmentation.png',
#  'ISIC_0000109_segmentation.png',
#  'ISIC_0013839_segmentation.png',
#  'ISIC_0014511_segmentation.png',
#  'ISIC_0012897_segmentation.png',
#  'ISIC_0005620_segmentation.png',
#  'ISIC_0010329_segmentation.png',
#  'ISIC_0010448_segmentation.png',
#  'ISIC_0015980_segmentation.png',
#  'ISIC_0015016_segmentation.png',
#  'ISIC_0010228_segmentation.png',
#  'ISIC_0013425_segmentation.png',
#  'ISIC_0014527_segmentation.png',
#  'ISIC_0009964_segmentation.png',
#  'ISIC_0012311_segmentation.png',
#  'ISIC_0014779_segmentation.png',
#  'ISIC_0008207_segmentation.png',
#  'ISIC_0014633_segmentation.png',
#  'ISIC_0014596_segmentation.png',
#  'ISIC_0012871_segmentation.png',
#  'ISIC_0014908_segmentation.png',
#  'ISIC_0014947_segmentation.png',
#  'ISIC_0012511_segmentation.png',
#  'ISIC_0000011_segmentation.png',
#  'ISIC_0013269_segmentation.png',
#  'ISIC_0012381_segmentation.png',
#  'ISIC_0000146_segmentation.png',
#  'ISIC_0012306_segmentation.png',
#  'ISIC_0010449_segmentation.png',
#  'ISIC_0013879_segmentation.png',
#  'ISIC_0002806_segmentation.png',
#  'ISIC_0000517_segmentation.png',
#  'ISIC_0012178_segmentation.png',
#  'ISIC_0015936_segmentation.png',
#  'ISIC_0016029_segmentation.png',
#  'ISIC_0000006_segmentation.png',
#  'ISIC_0013891_segmentation.png',
#  'ISIC_0008998_segmentation.png',
#  'ISIC_0009971_segmentation.png',
#  'ISIC_0015482_segmentation.png',
#  'ISIC_0001126_segmentation.png',
#  'ISIC_0013164_segmentation.png',
#  'ISIC_0014438_segmentation.png',
#  'ISIC_0011165_segmentation.png',
#  'ISIC_0012338_segmentation.png',
#  'ISIC_0010342_segmentation.png',
#  'ISIC_0014969_segmentation.png',
#  'ISIC_0015941_segmentation.png',
#  'ISIC_0000131_segmentation.png',
#  'ISIC_0013643_segmentation.png',
#  'ISIC_0013012_segmentation.png',
#  'ISIC_0012281_segmentation.png',
#  'ISIC_0011300_segmentation.png',
#  'ISIC_0010483_segmentation.png',
#  'ISIC_0012711_segmentation.png',
#  'ISIC_0000170_segmentation.png',
#  'ISIC_0010361_segmentation.png',
#  'ISIC_0015468_segmentation.png',
#  'ISIC_0012135_segmentation.png',
#  'ISIC_0014746_segmentation.png',
#  'ISIC_0014680_segmentation.png',
#  'ISIC_0013166_segmentation.png',
#  'ISIC_0014554_segmentation.png',
#  'ISIC_0013796_segmentation.png',
#  'ISIC_0009995_segmentation.png',
#  'ISIC_0014682_segmentation.png',
#  'ISIC_0011115_segmentation.png',
#  'ISIC_0015950_segmentation.png',
#  'ISIC_0011356_segmentation.png',
#  'ISIC_0006612_segmentation.png',
#  'ISIC_0009879_segmentation.png',
#  'ISIC_0009910_segmentation.png',
#  'ISIC_0009932_segmentation.png',
#  'ISIC_0010174_segmentation.png',
#  'ISIC_0013430_segmentation.png',
#  'ISIC_0000135_segmentation.png',
#  'ISIC_0013652_segmentation.png',
#  'ISIC_0015963_segmentation.png',
#  'ISIC_0012506_segmentation.png',
#  'ISIC_0014525_segmentation.png',
#  'ISIC_0012494_segmentation.png',
#  'ISIC_0000154_segmentation.png',
#  'ISIC_0012212_segmentation.png',
#  'ISIC_0000315_segmentation.png',
#  'ISIC_0013664_segmentation.png',
#  'ISIC_0009936_segmentation.png',
#  'ISIC_0013233_segmentation.png',
#  'ISIC_0012681_segmentation.png',
#  'ISIC_0012332_segmentation.png',
#  'ISIC_0014963_segmentation.png',
#  'ISIC_0000023_segmentation.png',
#  'ISIC_0001216_segmentation.png',
#  'ISIC_0010023_segmentation.png',
#  'ISIC_0016008_segmentation.png',
#  'ISIC_0015201_segmentation.png',
#  'ISIC_0015989_segmentation.png',
#  'ISIC_0000080_segmentation.png',
#  'ISIC_0014324_segmentation.png',
#  'ISIC_0013165_segmentation.png',
#  'ISIC_0011339_segmentation.png',
#  'ISIC_0013527_segmentation.png',
#  'ISIC_0000042_segmentation.png',
#  'ISIC_0011135_segmentation.png',
#  'ISIC_0015184_segmentation.png',
#  'ISIC_0010202_segmentation.png',
#  'ISIC_0015232_segmentation.png',
#  'ISIC_0015108_segmentation.png',
#  'ISIC_0000295_segmentation.png',
#  'ISIC_0014441_segmentation.png',
#  'ISIC_0009599_segmentation.png',
#  'ISIC_0012674_segmentation.png',
#  'ISIC_0011382_segmentation.png',
#  'ISIC_0004168_segmentation.png',
#  'ISIC_0000364_segmentation.png',
#  'ISIC_0014868_segmentation.png',
#  'ISIC_0012685_segmentation.png',
#  'ISIC_0000268_segmentation.png',
#  'ISIC_0014945_segmentation.png',
#  'ISIC_0002489_segmentation.png',
#  'ISIC_0013636_segmentation.png',
#  'ISIC_0013599_segmentation.png',
#  'ISIC_0013656_segmentation.png',
#  'ISIC_0014347_segmentation.png',
#  'ISIC_0000488_segmentation.png',
#  'ISIC_0011218_segmentation.png',
#  'ISIC_0012303_segmentation.png',
#  'ISIC_0010862_segmentation.png',
#  'ISIC_0014957_segmentation.png',
#  'ISIC_0014794_segmentation.png',
#  'ISIC_0002374_segmentation.png',
#  'ISIC_0000396_segmentation.png',
#  'ISIC_0013561_segmentation.png',
#  'ISIC_0012664_segmentation.png',
#  'ISIC_0010588_segmentation.png',
#  'ISIC_0011323_segmentation.png',
#  'ISIC_0016058_segmentation.png',
#  'ISIC_0000514_segmentation.png',
#  'ISIC_0013572_segmentation.png',
#  'ISIC_0010074_segmentation.png',
#  'ISIC_0012887_segmentation.png',
#  'ISIC_0015526_segmentation.png',
#  'ISIC_0014911_segmentation.png',
#  'ISIC_0014651_segmentation.png',
#  'ISIC_0014543_segmentation.png',
#  'ISIC_0013676_segmentation.png',
#  'ISIC_0013498_segmentation.png',
#  'ISIC_0011324_segmentation.png',
#  'ISIC_0013958_segmentation.png',
#  'ISIC_0013807_segmentation.png',
#  'ISIC_0013597_segmentation.png',
#  'ISIC_0015953_segmentation.png',
#  'ISIC_0011084_segmentation.png',
#  'ISIC_0012167_segmentation.png',
#  'ISIC_0015115_segmentation.png',
#  'ISIC_0013929_segmentation.png',
#  'ISIC_0012238_segmentation.png',
#  'ISIC_0014830_segmentation.png',
#  'ISIC_0013775_segmentation.png',
#  'ISIC_0012880_segmentation.png',
#  'ISIC_0012435_segmentation.png',
#  'ISIC_0013443_segmentation.png',
#  'ISIC_0009940_segmentation.png',
#  'ISIC_0015244_segmentation.png',
#  'ISIC_0014931_segmentation.png',
#  'ISIC_0012662_segmentation.png',
#  'ISIC_0015019_segmentation.png',
#  'ISIC_0013169_segmentation.png',
#  'ISIC_0016040_segmentation.png',
#  'ISIC_0012156_segmentation.png',
#  'ISIC_0014410_segmentation.png',
#  'ISIC_0010591_segmentation.png',
#  'ISIC_0014815_segmentation.png',
#  'ISIC_0009934_segmentation.png',
#  'ISIC_0013355_segmentation.png',
#  'ISIC_0012445_segmentation.png',
#  'ISIC_0013702_segmentation.png',
#  'ISIC_0000482_segmentation.png',
#  'ISIC_0000337_segmentation.png',
#  'ISIC_0014397_segmentation.png',
#  'ISIC_0014973_segmentation.png',
#  'ISIC_0015163_segmentation.png',
#  'ISIC_0013023_segmentation.png',
#  'ISIC_0015150_segmentation.png',
#  'ISIC_0010494_segmentation.png',
#  'ISIC_0012143_segmentation.png',
#  'ISIC_0013635_segmentation.png',
#  'ISIC_0015293_segmentation.png',
#  'ISIC_0000197_segmentation.png',
#  'ISIC_0014501_segmentation.png',
#  'ISIC_0013044_segmentation.png',
#  'ISIC_0013277_segmentation.png',
#  'ISIC_0013039_segmentation.png',
#  'ISIC_0015160_segmentation.png',
#  'ISIC_0016052_segmentation.png',
#  'ISIC_0013813_segmentation.png',
#  'ISIC_0000416_segmentation.png',
#  'ISIC_0012330_segmentation.png',
#  'ISIC_0001103_segmentation.png',
#  'ISIC_0014787_segmentation.png',
#  'ISIC_0013579_segmentation.png',
#  'ISIC_0013737_segmentation.png',
#  'ISIC_0016004_segmentation.png',
#  'ISIC_0015079_segmentation.png',
#  'ISIC_0015958_segmentation.png',
#  'ISIC_0000496_segmentation.png',
#  'ISIC_0016056_segmentation.png',
#  'ISIC_0000521_segmentation.png',
#  'ISIC_0010379_segmentation.png',
#  'ISIC_0012126_segmentation.png',
#  'ISIC_0013618_segmentation.png',
#  'ISIC_0014806_segmentation.png',
#  'ISIC_0012873_segmentation.png',
#  'ISIC_0015241_segmentation.png',
#  'ISIC_0006940_segmentation.png',
#  'ISIC_0012742_segmentation.png',
#  'ISIC_0011317_segmentation.png',
#  'ISIC_0014688_segmentation.png',
#  'ISIC_0010094_segmentation.png',
#  'ISIC_0014173_segmentation.png',
#  'ISIC_0010599_segmentation.png',
#  'ISIC_0000458_segmentation.png',
#  'ISIC_0012658_segmentation.png',
#  'ISIC_0013984_segmentation.png',
#  'ISIC_0012260_segmentation.png',
#  'ISIC_0000513_segmentation.png',
#  'ISIC_0015064_segmentation.png',
#  'ISIC_0014772_segmentation.png',
#  'ISIC_0011306_segmentation.png',
#  'ISIC_0015593_segmentation.png',
#  'ISIC_0010219_segmentation.png',
#  'ISIC_0013007_segmentation.png',
#  'ISIC_0010169_segmentation.png',
#  'ISIC_0012348_segmentation.png',
#  'ISIC_0013772_segmentation.png',
#  'ISIC_0010370_segmentation.png',
#  'ISIC_0010229_segmentation.png',
#  'ISIC_0014770_segmentation.png',
#  'ISIC_0013094_segmentation.png',
#  'ISIC_0014739_segmentation.png',
#  'ISIC_0016048_segmentation.png',
#  'ISIC_0010468_segmentation.png',
#  'ISIC_0000332_segmentation.png',
#  'ISIC_0016036_segmentation.png',
#  'ISIC_0000476_segmentation.png',
#  'ISIC_0013414_segmentation.png',
#  'ISIC_0011345_segmentation.png',
#  'ISIC_0015563_segmentation.png',
#  'ISIC_0013244_segmentation.png',
#  'ISIC_0000193_segmentation.png',
#  'ISIC_0013383_segmentation.png',
#  'ISIC_0010047_segmentation.png',
#  'ISIC_0013230_segmentation.png',
#  'ISIC_0011322_segmentation.png',
#  'ISIC_0012224_segmentation.png',
#  'ISIC_0013335_segmentation.png',
#  'ISIC_0016007_segmentation.png',
#  'ISIC_0013189_segmentation.png',
#  'ISIC_0013977_segmentation.png',
#  'ISIC_0012203_segmentation.png',
#  'ISIC_0013176_segmentation.png',
#  'ISIC_0012201_segmentation.png',
#  'ISIC_0006914_segmentation.png',
#  'ISIC_0010337_segmentation.png',
#  'ISIC_0014692_segmentation.png',
#  'ISIC_0011144_segmentation.png',
#  'ISIC_0014156_segmentation.png',
#  'ISIC_0010567_segmentation.png',
#  'ISIC_0009994_segmentation.png',
#  'ISIC_0011303_segmentation.png',
#  'ISIC_0011327_segmentation.png',
#  'ISIC_0003462_segmentation.png',
#  'ISIC_0014786_segmentation.png',
#  'ISIC_0014337_segmentation.png',
#  'ISIC_0009969_segmentation.png',
#  'ISIC_0013400_segmentation.png',
#  'ISIC_0009931_segmentation.png',
#  'ISIC_0015258_segmentation.png',
#  'ISIC_0000050_segmentation.png',
#  'ISIC_0005639_segmentation.png',
#  'ISIC_0013995_segmentation.png',
#  'ISIC_0012770_segmentation.png',
#  'ISIC_0015412_segmentation.png',
#  'ISIC_0014825_segmentation.png',
#  'ISIC_0012789_segmentation.png',
#  'ISIC_0000520_segmentation.png',
#  'ISIC_0000355_segmentation.png',
#  'ISIC_0012379_segmentation.png',
#  'ISIC_0010565_segmentation.png',
#  'ISIC_0014317_segmentation.png',
#  'ISIC_0013032_segmentation.png',
#  'ISIC_0002780_segmentation.png',
#  'ISIC_0012464_segmentation.png',
#  'ISIC_0013663_segmentation.png',
#  'ISIC_0000376_segmentation.png',
#  'ISIC_0000252_segmentation.png',
#  'ISIC_0012155_segmentation.png',
#  'ISIC_0015220_segmentation.png',
#  'ISIC_0009945_segmentation.png',
#  'ISIC_0012191_segmentation.png',
#  'ISIC_0012134_segmentation.png',
#  'ISIC_0014603_segmentation.png',
#  'ISIC_0013109_segmentation.png',
#  'ISIC_0013981_segmentation.png',
#  'ISIC_0014127_segmentation.png',
#  'ISIC_0014623_segmentation.png',
#  'ISIC_0015170_segmentation.png',
#  'ISIC_0014729_segmentation.png',
#  'ISIC_0015313_segmentation.png',
#  'ISIC_0014831_segmentation.png',
#  'ISIC_0000491_segmentation.png',
#  'ISIC_0015997_segmentation.png',
#  'ISIC_0011176_segmentation.png',
#  'ISIC_0000545_segmentation.png',
#  'ISIC_0015966_segmentation.png',
#  'ISIC_0000370_segmentation.png',
#  'ISIC_0013695_segmentation.png',
#  'ISIC_0015124_segmentation.png',
#  'ISIC_0012544_segmentation.png',
#  'ISIC_0013512_segmentation.png',
#  'ISIC_0013525_segmentation.png',
#  'ISIC_0014360_segmentation.png',
#  'ISIC_0015395_segmentation.png',
#  'ISIC_0011343_segmentation.png',
#  'ISIC_0002353_segmentation.png',
#  'ISIC_0009035_segmentation.png',
#  'ISIC_0010847_segmentation.png',
#  'ISIC_0010435_segmentation.png',
#  'ISIC_0011123_segmentation.png',
#  'ISIC_0000518_segmentation.png',
#  'ISIC_0010173_segmentation.png',
#  'ISIC_0015993_segmentation.png',
#  'ISIC_0000357_segmentation.png',
#  'ISIC_0011082_segmentation.png',
#  'ISIC_0000421_segmentation.png',
#  'ISIC_0000176_segmentation.png',
#  'ISIC_0015173_segmentation.png',
#  'ISIC_0001427_segmentation.png',
#  'ISIC_0000087_segmentation.png',
#  'ISIC_0000325_segmentation.png',
#  'ISIC_0000198_segmentation.png',
#  'ISIC_0014696_segmentation.png',
#  'ISIC_0014174_segmentation.png',
#  'ISIC_0014743_segmentation.png',
#  'ISIC_0012823_segmentation.png',
#  'ISIC_0010348_segmentation.png',
#  'ISIC_0015224_segmentation.png',
#  'ISIC_0000115_segmentation.png',
#  'ISIC_0000242_segmentation.png',
#  'ISIC_0000324_segmentation.png',
#  'ISIC_0010061_segmentation.png',
#  'ISIC_0015211_segmentation.png',
#  'ISIC_0000548_segmentation.png',
#  'ISIC_0012814_segmentation.png',
#  'ISIC_0014930_segmentation.png',
#  'ISIC_0014162_segmentation.png',
#  'ISIC_0000457_segmentation.png',
#  'ISIC_0009970_segmentation.png',
#  'ISIC_0014605_segmentation.png',
#  'ISIC_0012956_segmentation.png',
#  'ISIC_0000222_segmentation.png',
#  'ISIC_0010105_segmentation.png',
#  'ISIC_0014850_segmentation.png',
#  'ISIC_0011353_segmentation.png',
#  'ISIC_0013549_segmentation.png',
#  'ISIC_0012325_segmentation.png',
#  'ISIC_0000133_segmentation.png',
#  'ISIC_0014843_segmentation.png',
#  'ISIC_0010332_segmentation.png',
#  'ISIC_0011208_segmentation.png',
#  'ISIC_0015291_segmentation.png',
#  'ISIC_0012351_segmentation.png',
#  'ISIC_0009898_segmentation.png',
#  'ISIC_0013888_segmentation.png',
#  'ISIC_0010374_segmentation.png',
#  'ISIC_0011130_segmentation.png',
#  'ISIC_0013580_segmentation.png',
#  'ISIC_0012777_segmentation.png',
#  'ISIC_0014434_segmentation.png',
#  'ISIC_0011336_segmentation.png',
#  'ISIC_0000461_segmentation.png',
#  'ISIC_0000184_segmentation.png',
#  'ISIC_0010044_segmentation.png',
#  'ISIC_0002206_segmentation.png',
#  'ISIC_0015037_segmentation.png',
#  'ISIC_0010571_segmentation.png',
#  'ISIC_0001133_segmentation.png',
#  'ISIC_0005000_segmentation.png',
#  'ISIC_0000420_segmentation.png',
#  'ISIC_0000539_segmentation.png',
#  'ISIC_0000408_segmentation.png',
#  'ISIC_0001105_segmentation.png',
#  'ISIC_0012333_segmentation.png',
#  'ISIC_0013969_segmentation.png',
#  'ISIC_0013595_segmentation.png',
#  'ISIC_0013835_segmentation.png',
#  'ISIC_0014983_segmentation.png',
#  'ISIC_0013219_segmentation.png',
#  'ISIC_0000204_segmentation.png',
#  'ISIC_0002836_segmentation.png',
#  'ISIC_0014769_segmentation.png',
#  'ISIC_0010458_segmentation.png',
#  'ISIC_0012877_segmentation.png',
#  'ISIC_0010205_segmentation.png',
#  'ISIC_0013075_segmentation.png',
#  'ISIC_0000230_segmentation.png',
#  'ISIC_0012284_segmentation.png',
#  'ISIC_0014919_segmentation.png',
#  'ISIC_0013405_segmentation.png',
#  'ISIC_0014217_segmentation.png',
#  'ISIC_0012722_segmentation.png',
#  'ISIC_0012855_segmentation.png',
#  'ISIC_0000463_segmentation.png',
#  'ISIC_0011334_segmentation.png',
#  'ISIC_0010006_segmentation.png',
#  'ISIC_0012213_segmentation.png',
#  'ISIC_0000065_segmentation.png',
#  'ISIC_0000032_segmentation.png',
#  'ISIC_0009902_segmentation.png',
#  'ISIC_0010367_segmentation.png',
#  'ISIC_0010597_segmentation.png',
#  'ISIC_0000196_segmentation.png',
#  'ISIC_0010574_segmentation.png',
#  'ISIC_0008992_segmentation.png',
#  'ISIC_0013925_segmentation.png',
#  'ISIC_0000288_segmentation.png',
#  'ISIC_0013304_segmentation.png',
#  'ISIC_0001186_segmentation.png',
#  'ISIC_0000056_segmentation.png',
#  'ISIC_0014625_segmentation.png',
#  'ISIC_0010339_segmentation.png',
#  'ISIC_0015276_segmentation.png',
#  'ISIC_0011127_segmentation.png',
#  'ISIC_0011137_segmentation.png',
#  'ISIC_0014664_segmentation.png',
#  'ISIC_0013517_segmentation.png',
#  'ISIC_0010317_segmentation.png',
#  'ISIC_0012442_segmentation.png',
#  'ISIC_0002469_segmentation.png',
#  'ISIC_0014163_segmentation.png',
#  'ISIC_0014807_segmentation.png',
#  'ISIC_0001871_segmentation.png',
#  'ISIC_0013798_segmentation.png',
#  'ISIC_0006982_segmentation.png',
#  'ISIC_0000181_segmentation.png',
#  'ISIC_0010075_segmentation.png',
#  'ISIC_0006193_segmentation.png',
#  'ISIC_0000378_segmentation.png',
#  'ISIC_0013961_segmentation.png',
#  'ISIC_0014844_segmentation.png',
#  'ISIC_0012329_segmentation.png',
#  'ISIC_0016033_segmentation.png',
#  'ISIC_0014949_segmentation.png',
#  'ISIC_0015485_segmentation.png',
#  'ISIC_0000258_segmentation.png',
#  'ISIC_0000132_segmentation.png',
#  'ISIC_0013360_segmentation.png',
#  'ISIC_0012550_segmentation.png',
#  'ISIC_0013766_segmentation.png',
#  'ISIC_0000107_segmentation.png',
#  'ISIC_0013315_segmentation.png',
#  'ISIC_0000507_segmentation.png',
#  'ISIC_0013671_segmentation.png',
#  'ISIC_0000192_segmentation.png',
#  'ISIC_0000380_segmentation.png',
#  'ISIC_0012095_segmentation.png',
#  'ISIC_0015559_segmentation.png',
#  'ISIC_0015967_segmentation.png',
#  'ISIC_0015040_segmentation.png',
#  'ISIC_0001299_segmentation.png',
#  'ISIC_0010330_segmentation.png',
#  'ISIC_0010349_segmentation.png',
#  'ISIC_0011360_segmentation.png',
#  'ISIC_0013249_segmentation.png',
#  'ISIC_0014302_segmentation.png',
#  'ISIC_0010185_segmentation.png',
#  'ISIC_0014108_segmentation.png',
#  'ISIC_0015636_segmentation.png',
#  'ISIC_0009758_segmentation.png',
#  'ISIC_0013319_segmentation.png',
#  'ISIC_0000311_segmentation.png',
#  'ISIC_0010235_segmentation.png',
#  'ISIC_0010351_segmentation.png',
#  'ISIC_0014702_segmentation.png',
#  'ISIC_0009919_segmentation.png',
#  'ISIC_0005666_segmentation.png',
#  'ISIC_0015125_segmentation.png',
#  'ISIC_0000549_segmentation.png',
#  'ISIC_0014080_segmentation.png',
#  'ISIC_0000327_segmentation.png',
#  'ISIC_0011150_segmentation.png',
#  'ISIC_0009564_segmentation.png',
#  'ISIC_0015057_segmentation.png',
#  'ISIC_0001134_segmentation.png',
#  'ISIC_0000368_segmentation.png',
#  'ISIC_0000228_segmentation.png',
#  'ISIC_0013501_segmentation.png',
#  'ISIC_0000361_segmentation.png',
#  'ISIC_0013385_segmentation.png',
#  'ISIC_0010476_segmentation.png',
#  'ISIC_0014229_segmentation.png',
#  'ISIC_0000041_segmentation.png',
#  'ISIC_0010212_segmentation.png',
#  'ISIC_0012257_segmentation.png',
#  'ISIC_0014336_segmentation.png',
#  'ISIC_0010247_segmentation.png',
#  'ISIC_0000269_segmentation.png',
#  'ISIC_0000487_segmentation.png',
#  'ISIC_0015990_segmentation.png',
#  'ISIC_0013434_segmentation.png',
#  'ISIC_0010584_segmentation.png',
#  'ISIC_0011110_segmentation.png',
#  'ISIC_0015641_segmentation.png',
#  'ISIC_0014800_segmentation.png',
#  'ISIC_0014601_segmentation.png',
#  'ISIC_0014526_segmentation.png',
#  'ISIC_0011367_segmentation.png',
#  'ISIC_0000012_segmentation.png',
#  'ISIC_0014658_segmentation.png',
#  'ISIC_0000027_segmentation.png',
#  'ISIC_0009982_segmentation.png',
#  'ISIC_0008294_segmentation.png',
#  'ISIC_0010010_segmentation.png',
#  'ISIC_0012523_segmentation.png',
#  'ISIC_0014958_segmentation.png',
#  'ISIC_0000519_segmentation.png',
#  'ISIC_0015510_segmentation.png',
#  'ISIC_0014785_segmentation.png',
#  'ISIC_0012683_segmentation.png',
#  'ISIC_0013096_segmentation.png',
#  'ISIC_0013567_segmentation.png',
#  'ISIC_0010587_segmentation.png',
#  'ISIC_0014316_segmentation.png',
#  'ISIC_0011347_segmentation.png',
#  'ISIC_0013962_segmentation.png',
#  'ISIC_0014835_segmentation.png',
#  'ISIC_0011205_segmentation.png',
#  'ISIC_0014393_segmentation.png',
#  'ISIC_0014694_segmentation.png',
#  'ISIC_0010066_segmentation.png',
#  'ISIC_0014876_segmentation.png',
#  'ISIC_0001148_segmentation.png',
#  'ISIC_0010340_segmentation.png',
#  'ISIC_0010257_segmentation.png',
#  'ISIC_0013896_segmentation.png',
#  'ISIC_0014726_segmentation.png',
#  'ISIC_0015638_segmentation.png',
#  'ISIC_0003174_segmentation.png',
#  'ISIC_0004715_segmentation.png',
#  'ISIC_0012323_segmentation.png',
#  'ISIC_0014349_segmentation.png',
#  'ISIC_0012726_segmentation.png',
#  'ISIC_0008116_segmentation.png',
#  'ISIC_0000009_segmentation.png',
#  'ISIC_0014559_segmentation.png',
#  'ISIC_0000542_segmentation.png',
#  'ISIC_0000218_segmentation.png',
#  'ISIC_0000448_segmentation.png',
#  'ISIC_0014037_segmentation.png',
#  'ISIC_0009975_segmentation.png',
#  'ISIC_0016006_segmentation.png',
#  'ISIC_0010592_segmentation.png',
#  'ISIC_0015190_segmentation.png',
#  'ISIC_0012360_segmentation.png',
#  'ISIC_0009860_segmentation.png',
#  'ISIC_0009974_segmentation.png',
#  'ISIC_0013204_segmentation.png',
#  'ISIC_0009928_segmentation.png',
#  'ISIC_0013719_segmentation.png',
#  'ISIC_0000111_segmentation.png',
#  'ISIC_0000126_segmentation.png',
#  'ISIC_0014576_segmentation.png',
#  'ISIC_0014573_segmentation.png',
#  'ISIC_0014503_segmentation.png',
#  'ISIC_0013070_segmentation.png',
#  'ISIC_0015166_segmentation.png',
#  'ISIC_0000239_segmentation.png',
#  'ISIC_0000274_segmentation.png',
#  'ISIC_0013072_segmentation.png',
#  'ISIC_0013777_segmentation.png',
#  'ISIC_0010848_segmentation.png',
#  'ISIC_0000480_segmentation.png',
#  'ISIC_0009921_segmentation.png',
#  'ISIC_0007760_segmentation.png',
#  'ISIC_0015368_segmentation.png',
#  'ISIC_0011079_segmentation.png',
#  'ISIC_0013828_segmentation.png',
#  'ISIC_0015998_segmentation.png',
#  'ISIC_0015974_segmentation.png',
#  'ISIC_0015185_segmentation.png',
#  'ISIC_0013274_segmentation.png',
#  'ISIC_0000307_segmentation.png',
#  'ISIC_0014897_segmentation.png',
#  'ISIC_0014090_segmentation.png',
#  'ISIC_0011386_segmentation.png',
#  'ISIC_0016026_segmentation.png',
#  'ISIC_0015972_segmentation.png',
#  'ISIC_0000201_segmentation.png',
#  'ISIC_0000247_segmentation.png',
#  'ISIC_0000190_segmentation.png',
#  'ISIC_0013603_segmentation.png',
#  'ISIC_0000246_segmentation.png',
#  'ISIC_0001423_segmentation.png',
#  'ISIC_0016066_segmentation.png',
#  'ISIC_0000251_segmentation.png',
#  'ISIC_0016070_segmentation.png',
#  'ISIC_0011173_segmentation.png',
#  'ISIC_0004985_segmentation.png',
#  'ISIC_0013378_segmentation.png',
#  'ISIC_0014657_segmentation.png',
#  'ISIC_0010320_segmentation.png',
#  'ISIC_0008403_segmentation.png',
#  'ISIC_0015133_segmentation.png',
#  'ISIC_0012177_segmentation.png',
#  'ISIC_0012508_segmentation.png',
#  'ISIC_0014117_segmentation.png',
#  'ISIC_0000223_segmentation.png',
#  'ISIC_0014545_segmentation.png',
#  'ISIC_0013621_segmentation.png',
#  'ISIC_0010590_segmentation.png',
#  'ISIC_0013213_segmentation.png',
#  'ISIC_0001184_segmentation.png',
#  'ISIC_0000129_segmentation.png',
#  'ISIC_0014081_segmentation.png',
#  'ISIC_0015255_segmentation.png',
#  'ISIC_0014637_segmentation.png',
#  'ISIC_0007693_segmentation.png',
#  'ISIC_0013678_segmentation.png',
#  'ISIC_0015614_segmentation.png',
#  'ISIC_0000365_segmentation.png',
#  'ISIC_0011358_segmentation.png',
#  'ISIC_0000481_segmentation.png',
#  'ISIC_0000543_segmentation.png',
#  'ISIC_0012230_segmentation.png',
#  'ISIC_0015401_segmentation.png',
#  'ISIC_0015981_segmentation.png',
#  'ISIC_0013001_segmentation.png',
#  'ISIC_0013310_segmentation.png',
#  'ISIC_0014714_segmentation.png',
#  'ISIC_0000148_segmentation.png',
#  'ISIC_0013112_segmentation.png',
#  'ISIC_0000263_segmentation.png',
#  'ISIC_0014795_segmentation.png',
#  'ISIC_0009883_segmentation.png',
#  'ISIC_0012478_segmentation.png',
#  'ISIC_0000470_segmentation.png',
#  'ISIC_0015167_segmentation.png',
#  'ISIC_0014716_segmentation.png',
#  'ISIC_0012092_segmentation.png',
#  'ISIC_0007528_segmentation.png',
#  'ISIC_0009927_segmentation.png',
#  'ISIC_0015436_segmentation.png',
#  'ISIC_0012720_segmentation.png',
#  'ISIC_0001254_segmentation.png',
#  'ISIC_0011352_segmentation.png',
#  'ISIC_0013816_segmentation.png',
#  'ISIC_0011124_segmentation.png',
#  'ISIC_0008541_segmentation.png',
#  'ISIC_0010605_segmentation.png',
#  'ISIC_0012473_segmentation.png',
#  'ISIC_0010034_segmentation.png',
#  'ISIC_0009896_segmentation.png',
#  'ISIC_0012902_segmentation.png',
#  'ISIC_0013568_segmentation.png',
#  'ISIC_0014537_segmentation.png',
#  'ISIC_0013996_segmentation.png',
#  'ISIC_0012268_segmentation.png',
#  'ISIC_0011162_segmentation.png',
#  'ISIC_0010024_segmentation.png',
#  'ISIC_0000202_segmentation.png',
#  'ISIC_0015139_segmentation.png',
#  'ISIC_0013248_segmentation.png',
#  'ISIC_0000443_segmentation.png',
#  'ISIC_0013581_segmentation.png',
#  'ISIC_0014164_segmentation.png',
#  'ISIC_0015250_segmentation.png',
#  'ISIC_0013150_segmentation.png',
#  'ISIC_0001212_segmentation.png',
#  'ISIC_0010054_segmentation.png',
#  'ISIC_0013966_segmentation.png',
#  'ISIC_0010055_segmentation.png',
#  'ISIC_0012551_segmentation.png',
#  'ISIC_0012475_segmentation.png',
#  'ISIC_0015202_segmentation.png',
#  'ISIC_0010019_segmentation.png',
#  'ISIC_0000407_segmentation.png',
#  'ISIC_0014869_segmentation.png',
#  'ISIC_0013184_segmentation.png',
#  'ISIC_0000220_segmentation.png',
#  'ISIC_0015355_segmentation.png',
#  'ISIC_0013738_segmentation.png',
#  'ISIC_0015566_segmentation.png',
#  'ISIC_0006795_segmentation.png',
#  'ISIC_0010463_segmentation.png',
#  'ISIC_0010255_segmentation.png',
#  'ISIC_0016041_segmentation.png',
#  'ISIC_0014233_segmentation.png',
#  'ISIC_0012837_segmentation.png',
#  'ISIC_0000554_segmentation.png',
#  'ISIC_0008507_segmentation.png',
#  'ISIC_0010201_segmentation.png',
#  'ISIC_0012539_segmentation.png',
#  'ISIC_0000073_segmentation.png',
#  'ISIC_0000035_segmentation.png',
#  'ISIC_0014823_segmentation.png',
#  'ISIC_0014094_segmentation.png',
#  'ISIC_0011139_segmentation.png',
#  'ISIC_0000524_segmentation.png',
#  'ISIC_0010249_segmentation.png',
#  'ISIC_0009993_segmentation.png',
#  'ISIC_0014775_segmentation.png',
#  'ISIC_0010576_segmentation.png',
#  'ISIC_0002879_segmentation.png',
#  'ISIC_0013998_segmentation.png',
#  'ISIC_0009252_segmentation.png',
#  'ISIC_0015219_segmentation.png',
#  'ISIC_0009953_segmentation.png',
#  'ISIC_0009083_segmentation.png',
#  'ISIC_0009504_segmentation.png',
#  'ISIC_0012981_segmentation.png',
#  'ISIC_0012654_segmentation.png',
#  'ISIC_0015041_segmentation.png',
#  ...]

# %%
mask2=[file.split('_segmentation')[0] for file in masklist if file.endswith(".png") and file.startswith("ISIC")]
test_pics=[file for file in pics if file.split('.jpeg')[0] in mask2]

# %%
ids=test_pics
print("No. of images = ", len(ids))
# Out:
# No. of images =  2186

# %%
test_pics[1].split('.')[0]
# Out:
# 'ISIC_0012224'

# %%
X = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
y = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)

# %%
# tqdm is used to display the progress bar
for n, id_ in tqdm_notebook(enumerate(ids), total=len(ids)):
#for n, id_ in enumerate(ids):
    # Load images
    img = load_img("/home/seo/ISIC DATA/"+str(id_), grayscale=True)
    x_img = img_to_array(img)
    x_img = resize(x_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Load masks
    mask = img_to_array(load_img("/home/seo/Masks/"+id_.split('.')[0]+'_segmentation.png', grayscale=True))
    mask = resize(mask, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Save images
    X[n] = x_img/255.0
    y[n] = mask/255.0
# Out:
# HBox(children=(IntProgress(value=0, max=2186), HTML(value='')))
# /home/seo/environments/my_env/lib/python3.6/site-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
#import pickle
#with open('X.pickle', 'wb') as f:
#    pickle.dump(X, f)
#with open('y.pickle', 'wb') as f:
#    pickle.dump(y, f)

# %%
import pickle

X=pickle.load(open('X.pickle',"rb"))
y=pickle.load(open('y.pickle',"rb"))

# %%
# Split train and valid
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 128, 16) 64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 128, 128, 16) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 64, 16)   0           activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64, 64, 16)   0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 32)   4640        dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 64, 32)   128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 32, 32)   0           activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   18496       dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 64)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 16, 64)   0           activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 16, 16, 64)   0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 128)  73856       dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 128)  512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 8, 8, 128)    0           activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 8, 8, 128)    0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 256)    295168      dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 256)    1024        conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 256)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 16, 16, 128)  295040      activation_46[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_9[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 16, 16, 256)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 128)  295040      dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 64)   73792       activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 128)  0           conv2d_transpose_10[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 32, 32, 128)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 64)   73792       dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 64)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 64, 64, 32)   18464       activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_11[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 64, 64, 64)   0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 32)   18464       dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 64, 64, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 64, 64, 32)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 128, 128, 16) 4624        activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_12[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 128, 128, 32) 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 16) 4624        dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 128, 128, 16) 64          conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 16) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 1)  17          activation_54[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
import pickle

model=pickle.load(open('model.pickle',"rb"))

# %%
results = model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=callbacks,\
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 1967 samples, validate on 219 samples
# Epoch 1/50
# 1967/1967 [==============================] - 165s 84ms/step - loss: 0.3907 - acc: 0.8372 - val_loss: 0.5053 - val_acc: 0.8372
#
# Epoch 00001: val_loss improved from inf to 0.50528, saving model to model-tgs-salt.h5
# Epoch 2/50
# 1967/1967 [==============================] - 156s 79ms/step - loss: 0.2518 - acc: 0.8867 - val_loss: 0.2127 - val_acc: 0.8884
#
# Epoch 00002: val_loss improved from 0.50528 to 0.21273, saving model to model-tgs-salt.h5
# Epoch 3/50
# 1967/1967 [==============================] - 157s 80ms/step - loss: 0.2134 - acc: 0.8919 - val_loss: 0.1934 - val_acc: 0.8979
#
# Epoch 00003: val_loss improved from 0.21273 to 0.19344, saving model to model-tgs-salt.h5
# Epoch 4/50
# 1967/1967 [==============================] - 156s 79ms/step - loss: 0.1909 - acc: 0.8960 - val_loss: 0.1980 - val_acc: 0.8926
#
# Epoch 00004: val_loss did not improve from 0.19344
# Epoch 5/50
# 1967/1967 [==============================] - 154s 78ms/step - loss: 0.1827 - acc: 0.8975 - val_loss: 0.1859 - val_acc: 0.8974
#
# Epoch 00005: val_loss improved from 0.19344 to 0.18590, saving model to model-tgs-salt.h5
# Epoch 6/50
# 1967/1967 [==============================] - 156s 79ms/step - loss: 0.1633 - acc: 0.9032 - val_loss: 0.1887 - val_acc: 0.8923
#
# Epoch 00006: val_loss did not improve from 0.18590
# Epoch 7/50
# 1967/1967 [==============================] - 154s 78ms/step - loss: 0.1622 - acc: 0.9022 - val_loss: 0.1755 - val_acc: 0.8988
#
# Epoch 00007: val_loss improved from 0.18590 to 0.17550, saving model to model-tgs-salt.h5
# Epoch 8/50
# 1967/1967 [==============================] - 158s 80ms/step - loss: 0.1566 - acc: 0.9040 - val_loss: 0.1628 - val_acc: 0.9012
#
# Epoch 00008: val_loss improved from 0.17550 to 0.16279, saving model to model-tgs-salt.h5
# Epoch 9/50
# 1967/1967 [==============================] - 153s 78ms/step - loss: 0.1465 - acc: 0.9067 - val_loss: 0.1756 - val_acc: 0.8944
#
# Epoch 00009: val_loss did not improve from 0.16279
# Epoch 10/50
# 1967/1967 [==============================] - 153s 78ms/step - loss: 0.1406 - acc: 0.9083 - val_loss: 0.1769 - val_acc: 0.8976
#
# Epoch 00010: val_loss did not improve from 0.16279
# Epoch 11/50
# 1967/1967 [==============================] - 153s 78ms/step - loss: 0.1383 - acc: 0.9090 - val_loss: 0.2456 - val_acc: 0.8808
#
# Epoch 00011: val_loss did not improve from 0.16279
# Epoch 12/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.1366 - acc: 0.9084 - val_loss: 0.2628 - val_acc: 0.8791
#
# Epoch 00012: val_loss did not improve from 0.16279
# Epoch 13/50
# 1967/1967 [==============================] - 151s 77ms/step - loss: 0.1330 - acc: 0.9099 - val_loss: 0.1545 - val_acc: 0.9048
#
# Epoch 00013: val_loss improved from 0.16279 to 0.15451, saving model to model-tgs-salt.h5
# Epoch 14/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.1248 - acc: 0.9130 - val_loss: 0.1822 - val_acc: 0.8973
#
# Epoch 00014: val_loss did not improve from 0.15451
# Epoch 15/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.1192 - acc: 0.9148 - val_loss: 0.3535 - val_acc: 0.8543
#
# Epoch 00015: val_loss did not improve from 0.15451
# Epoch 16/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.1154 - acc: 0.9161 - val_loss: 0.2392 - val_acc: 0.8808
#
# Epoch 00016: val_loss did not improve from 0.15451
# Epoch 17/50
# 1967/1967 [==============================] - 150s 76ms/step - loss: 0.1153 - acc: 0.9163 - val_loss: 0.1419 - val_acc: 0.9073
#
# Epoch 00017: val_loss improved from 0.15451 to 0.14193, saving model to model-tgs-salt.h5
# Epoch 18/50
# 1967/1967 [==============================] - 154s 78ms/step - loss: 0.1065 - acc: 0.9194 - val_loss: 0.1540 - val_acc: 0.9063
#
# Epoch 00018: val_loss did not improve from 0.14193
# Epoch 19/50
# 1967/1967 [==============================] - 153s 78ms/step - loss: 0.1048 - acc: 0.9193 - val_loss: 0.1525 - val_acc: 0.9084
#
# Epoch 00019: val_loss did not improve from 0.14193
# Epoch 20/50
# 1967/1967 [==============================] - 155s 79ms/step - loss: 0.1049 - acc: 0.9194 - val_loss: 0.2356 - val_acc: 0.8897
#
# Epoch 00020: val_loss did not improve from 0.14193
# Epoch 21/50
# 1967/1967 [==============================] - 154s 78ms/step - loss: 0.0998 - acc: 0.9213 - val_loss: 0.1763 - val_acc: 0.9039
#
# Epoch 00021: val_loss did not improve from 0.14193
# Epoch 22/50
# 1967/1967 [==============================] - 153s 78ms/step - loss: 0.0988 - acc: 0.9217 - val_loss: 0.1671 - val_acc: 0.8997
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00022: val_loss did not improve from 0.14193
# Epoch 23/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.0832 - acc: 0.9276 - val_loss: 0.1359 - val_acc: 0.9109
#
# Epoch 00023: val_loss improved from 0.14193 to 0.13590, saving model to model-tgs-salt.h5
# Epoch 24/50
# 1967/1967 [==============================] - 152s 77ms/step - loss: 0.0769 - acc: 0.9297 - val_loss: 0.1254 - val_acc: 0.9145
#
# Epoch 00024: val_loss improved from 0.13590 to 0.12538, saving model to model-tgs-salt.h5
# Epoch 25/50
# 1967/1967 [==============================] - 150s 76ms/step - loss: 0.0775 - acc: 0.9293 - val_loss: 0.1248 - val_acc: 0.9147
#
# Epoch 00025: val_loss improved from 0.12538 to 0.12479, saving model to model-tgs-salt.h5
# Epoch 26/50
# 1967/1967 [==============================] - 149s 76ms/step - loss: 0.0740 - acc: 0.9307 - val_loss: 0.1251 - val_acc: 0.9152
#
# Epoch 00026: val_loss did not improve from 0.12479
# Epoch 27/50
# 1967/1967 [==============================] - 154s 78ms/step - loss: 0.0742 - acc: 0.9305 - val_loss: 0.1299 - val_acc: 0.9147
#
# Epoch 00027: val_loss did not improve from 0.12479
# Epoch 28/50
# 1967/1967 [==============================] - 151s 77ms/step - loss: 0.0731 - acc: 0.9308 - val_loss: 0.1296 - val_acc: 0.9146
#
# Epoch 00028: val_loss did not improve from 0.12479
# Epoch 29/50
# 1967/1967 [==============================] - 147s 75ms/step - loss: 0.0738 - acc: 0.9304 - val_loss: 0.1274 - val_acc: 0.9153
#
# Epoch 00029: val_loss did not improve from 0.12479
# Epoch 30/50
# 1967/1967 [==============================] - 148s 75ms/step - loss: 0.0714 - acc: 0.9314 - val_loss: 0.1265 - val_acc: 0.9151
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00030: val_loss did not improve from 0.12479
# Epoch 31/50
# 1967/1967 [==============================] - 148s 75ms/step - loss: 0.0714 - acc: 0.9314 - val_loss: 0.1280 - val_acc: 0.9153
#
# Epoch 00031: val_loss did not improve from 0.12479
# Epoch 32/50
# 1967/1967 [==============================] - 147s 75ms/step - loss: 0.0696 - acc: 0.9319 - val_loss: 0.1296 - val_acc: 0.9153
#
# Epoch 00032: val_loss did not improve from 0.12479
# Epoch 33/50
# 1967/1967 [==============================] - 147s 75ms/step - loss: 0.0694 - acc: 0.9320 - val_loss: 0.1296 - val_acc: 0.9153
#
# Epoch 00033: val_loss did not improve from 0.12479
# Epoch 34/50
# 1967/1967 [==============================] - 147s 75ms/step - loss: 0.0718 - acc: 0.9312 - val_loss: 0.1303 - val_acc: 0.9152
#
# Epoch 00034: val_loss did not improve from 0.12479
# Epoch 35/50
# 1967/1967 [==============================] - 148s 75ms/step - loss: 0.0691 - acc: 0.9322 - val_loss: 0.1296 - val_acc: 0.9153
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00035: val_loss did not improve from 0.12479
# Epoch 00035: early stopping

# %%
with open('fit_model.pickle', 'wb') as f:
    pickle.dump(results, f)
with open('model.pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
# Load best model
model.load_weights('model-tgs-salt.h5')

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 219/219 [==============================] - 3s 15ms/step
# [0.12478770655856285, 0.9146742436983814]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 1967/1967 [==============================] - 32s 16ms/step
# 219/219 [==============================] - 3s 15ms/step

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Seismic')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('mask')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('lesion Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('lesion Predicted binary');

# %%
model.predict
# Out:
# array([[[[0.02056259],
#          [0.01135471],
#          [0.00696769],
#          ...,
#          [0.00493675],
#          [0.00734469],
#          [0.01377928]],
#
#         [[0.01235697],
#          [0.00498125],
#          [0.00377953],
#          ...,
#          [0.00175995],
#          [0.0034048 ],
#          [0.00595498]],
#
#         [[0.00521007],
#          [0.0019733 ],
#          [0.0018934 ],
#          ...,
#          [0.00087786],
#          [0.00125757],
#          [0.00439262]],
#
#         ...,
#
#         [[0.00321138],
#          [0.00172943],
#          [0.00112593],
#          ...,
#          [0.00145444],
#          [0.00153783],
#          [0.00554913]],
#
#         [[0.00320408],
#          [0.00170469],
#          [0.00138107],
#          ...,
#          [0.00113258],
#          [0.00159371],
#          [0.00448486]],
#
#         [[0.01339301],
#          [0.0057677 ],
#          [0.00508249],
#          ...,
#          [0.00444284],
#          [0.00804201],
#          [0.00786838]]],
#
#
#        [[[0.01083416],
#          [0.00933412],
#          [0.00659329],
#          ...,
#          [0.00317901],
#          [0.00536028],
#          [0.01610327]],
#
#         [[0.01140741],
#          [0.0112839 ],
#          [0.00729701],
#          ...,
#          [0.00425357],
#          [0.00454673],
#          [0.00626299]],
#
#         [[0.00369173],
#          [0.00746164],
#          [0.0055505 ],
#          ...,
#          [0.00198069],
#          [0.00199232],
#          [0.00409666]],
#
#         ...,
#
#         [[0.00212824],
#          [0.00176093],
#          [0.00170058],
#          ...,
#          [0.00315621],
#          [0.00217921],
#          [0.00450611]],
#
#         [[0.00236276],
#          [0.00155386],
#          [0.00160396],
#          ...,
#          [0.00176606],
#          [0.00159183],
#          [0.00457239]],
#
#         [[0.01184192],
#          [0.00536028],
#          [0.00443316],
#          ...,
#          [0.0030565 ],
#          [0.00470498],
#          [0.00397912]]],
#
#
#        [[[0.0276024 ],
#          [0.01714343],
#          [0.00778916],
#          ...,
#          [0.0096103 ],
#          [0.01269299],
#          [0.02318957]],
#
#         [[0.02475417],
#          [0.01032799],
#          [0.00607988],
#          ...,
#          [0.00394025],
#          [0.00685924],
#          [0.01042506]],
#
#         [[0.01349798],
#          [0.00711897],
#          [0.0058817 ],
#          ...,
#          [0.00294709],
#          [0.00287464],
#          [0.0080654 ]],
#
#         ...,
#
#         [[0.0086284 ],
#          [0.00185269],
#          [0.00130916],
#          ...,
#          [0.0007818 ],
#          [0.00115451],
#          [0.00497299]],
#
#         [[0.00751337],
#          [0.00287795],
#          [0.00145403],
#          ...,
#          [0.00069693],
#          [0.00129315],
#          [0.00464123]],
#
#         [[0.02111048],
#          [0.00711259],
#          [0.00728846],
#          ...,
#          [0.00292918],
#          [0.00723082],
#          [0.00787944]]],
#
#
#        ...,
#
#
#        [[[0.01038542],
#          [0.0080049 ],
#          [0.00438967],
#          ...,
#          [0.00469694],
#          [0.00786886],
#          [0.02047464]],
#
#         [[0.00972652],
#          [0.00707418],
#          [0.00343716],
#          ...,
#          [0.0030919 ],
#          [0.00382125],
#          [0.01019844]],
#
#         [[0.00321633],
#          [0.00391904],
#          [0.00219855],
#          ...,
#          [0.00126615],
#          [0.00143859],
#          [0.00505033]],
#
#         ...,
#
#         [[0.00483596],
#          [0.00100833],
#          [0.00072607],
#          ...,
#          [0.00051337],
#          [0.00077844],
#          [0.00241083]],
#
#         [[0.0036861 ],
#          [0.00152165],
#          [0.00118139],
#          ...,
#          [0.00071743],
#          [0.00107464],
#          [0.00325158]],
#
#         [[0.01391923],
#          [0.00492921],
#          [0.00869134],
#          ...,
#          [0.00270918],
#          [0.00669864],
#          [0.00904822]]],
#
#
#        [[[0.01789281],
#          [0.00966507],
#          [0.00468412],
#          ...,
#          [0.00482213],
#          [0.00689802],
#          [0.01278856]],
#
#         [[0.01773021],
#          [0.0052079 ],
#          [0.00410649],
#          ...,
#          [0.00148451],
#          [0.00326216],
#          [0.00554025]],
#
#         [[0.00543448],
#          [0.00428227],
#          [0.00334767],
#          ...,
#          [0.00077018],
#          [0.00128818],
#          [0.00430587]],
#
#         ...,
#
#         [[0.00270665],
#          [0.00163692],
#          [0.00108841],
#          ...,
#          [0.001201  ],
#          [0.00084037],
#          [0.00200075]],
#
#         [[0.00273359],
#          [0.00153425],
#          [0.00127235],
#          ...,
#          [0.0011642 ],
#          [0.00101927],
#          [0.00387195]],
#
#         [[0.01228726],
#          [0.00518394],
#          [0.00445601],
#          ...,
#          [0.00241461],
#          [0.0075787 ],
#          [0.01229089]]],
#
#
#        [[[0.02623343],
#          [0.01539704],
#          [0.01052079],
#          ...,
#          [0.00470293],
#          [0.00744599],
#          [0.01440907]],
#
#         [[0.01476115],
#          [0.00572109],
#          [0.0052686 ],
#          ...,
#          [0.00160089],
#          [0.00383228],
#          [0.00641561]],
#
#         [[0.00672725],
#          [0.00291282],
#          [0.00368327],
#          ...,
#          [0.00124142],
#          [0.00143749],
#          [0.00499824]],
#
#         ...,
#
#         [[0.00521624],
#          [0.0017311 ],
#          [0.00130007],
#          ...,
#          [0.00081137],
#          [0.00066078],
#          [0.00176445]],
#
#         [[0.00444275],
#          [0.00260296],
#          [0.00175568],
#          ...,
#          [0.00077352],
#          [0.00077412],
#          [0.00303185]],
#
#         [[0.01491895],
#          [0.0064331 ],
#          [0.00700259],
#          ...,
#          [0.00198185],
#          [0.00584725],
#          [0.01048613]]]], dtype=float32)

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=0)

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=1)

# %%
# Check if valid data looks all right
plot_sample(X_valid, y_valid, preds_val, preds_val_t, ix=19)

# %%
with open('model_fitted.pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 128)  295040      activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 64)   73792       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 32)   18464       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 16) 4624        activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 1)  17          activation_18[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
type(X[1])
# Out:
# numpy.ndarray
